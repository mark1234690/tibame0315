# %% [markdown]
# <a href="https://colab.research.google.com/github/mark1234690/tibame0315/blob/main/%E3%80%8C%E3%80%8Cregression_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.datasets import load_diabetes
datas=load_diabetes()
df=pd.DataFrame(datas['data'],
        columns=datas['feature_names'])
df['Y']=datas['target']
df
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6      Y
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split
x = df.drop("Y", axis=1)
y = df["Y"]
x_np = np.array(x)
y_np = np.array(y)
x_train, x_test, y_train, y_test = train_test_split(x_np, y_np, test_size=0.1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (397, 10)
# (45, 10)
# (397,)
# (45,)

# %%
from sklearn.tree import DecisionTreeRegressor
reg=DecisionTreeRegressor(max_depth=3)
reg.fit(x_train , y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
fig=plt.figure(figsize=(14 , 14))
plot_tree(reg,
     feature_names=x.columns,
     filled=True)
# Out:
# [Text(0.5, 0.875, 's5 <= -0.0\nsquared_error = 5805.016\nsamples = 397\nvalue = 151.937'),
#  Text(0.25, 0.625, 'bmi <= 0.006\nsquared_error = 3299.67\nsamples = 207\nvalue = 112.826'),
#  Text(0.125, 0.375, 's3 <= 0.021\nsquared_error = 2224.922\nsamples = 163\nvalue = 98.699'),
#  Text(0.0625, 0.125, 'squared_error = 2819.078\nsamples = 86\nvalue = 111.058'),
#  Text(0.1875, 0.125, 'squared_error = 1200.197\nsamples = 77\nvalue = 84.896'),
#  Text(0.375, 0.375, 'bp <= 0.005\nsquared_error = 3803.088\nsamples = 44\nvalue = 165.159'),
#  Text(0.3125, 0.125, 'squared_error = 2263.085\nsamples = 23\nvalue = 140.043'),
#  Text(0.4375, 0.125, 'squared_error = 4042.222\nsamples = 21\nvalue = 192.667'),
#  Text(0.75, 0.625, 'bmi <= 0.056\nsquared_error = 5052.353\nsamples = 190\nvalue = 194.547'),
#  Text(0.625, 0.375, 'bmi <= -0.022\nsquared_error = 4447.28\nsamples = 149\nvalue = 177.953'),
#  Text(0.5625, 0.125, 'squared_error = 3066.008\nsamples = 34\nvalue = 139.147'),
# ...
